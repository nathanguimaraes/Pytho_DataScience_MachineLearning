# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv("df1", index_col=0)

# %%
df2 = pd.read_csv("df2")

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True) #stacked agrega os valores para a mesma barra
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot.hist(bins=50)#bins proporciona uma quebra nas barras
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.scatter(x='A', y='B',  cmap='inferno')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(1000, 2), columns=['A', 'B'])

# %%
df.plot.hexbin(x='A', y='B', gridsize=20) #criando mapa hexagonal
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>
