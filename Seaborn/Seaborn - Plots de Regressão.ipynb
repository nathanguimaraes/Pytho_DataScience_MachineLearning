# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#vamops fazer uma regressao entre o total da conta e a gorjeta paga 
sns.lmplot(x='total_bill', y='tip', data=tips,row='time', col='sex', hue='sex', markers=['o', 'v'], scatter_kws={'s':100})
#markers = alterar os marcadores 
#scatter_kws = altera o tamanho dos marcadores  criando um dicionairo
#col = com esse paramentro é possivel dividir em duas figuras diferente 
#row = com esse paramentro é possivel diovir as figuras em linhas
